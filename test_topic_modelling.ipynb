# %%
import pandas as pd
from topic_modelling import extract_topics_from_user_message, format_user_message

# %%
user_message = "way too expensive"

# %%
useful_cols_and_completed_df = pd.read_csv("snowflake_data/useful_cols_and_completed_df.csv")

# %%
for i, row in useful_cols_and_completed_df.iterrows():
    improvement_needed = row["NZ_RELATIONSHIP_IMPORTANT_IMPROVEMENT_CMT"]
    reason_for_given_nps = row["NZ_RELATIONSHIP_NPS_REASON_CMT"]

    user_message = format_user_message(improvement_needed=improvement_needed,
                                       reason_for_given_nps=reason_for_given_nps)
    if user_message:
        print(user_message)

        topics = extract_topics_from_user_message(user_message=user_message)
        print(topics)

        print("\n\n----------------------------------------------------------\n\n")
# Out:
# Improvement needed: Internet as I mentioned, pretty laggy
# Reason for given NPS: Amazing service just little laggy with the internet could do better.
#
# Overall no problem
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["internet_speed_issues", "internet_connectivity_issues"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['internet_speed_issues', 'internet_connectivity_issues']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Better value fibre
#
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["better_value_fibre"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['better_value_fibre']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Communication with customers before you merge with a spy network.
# Reason for given NPS: Your merger with the spies with no consultation with your customers.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["lack_of_communication", "merger_concerns"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['lack_of_communication', 'merger_concerns']}
#
#
# ----------------------------------------------------------
#
#
# Reason for given NPS: I’ve been with you for a number of years and have three broadband accounts and two phones and in that time I have found you to be very approachable when trying to set up a new device and generally you don’t have a long wait time when calling
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : []
# }
# {'detected_topics': [], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: I can't think of anything
# Reason for given NPS: Good service, no issues
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : []
# }
# {'detected_topics': [], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Rural internet
# Reason for given NPS: Great service
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : ["rural_internet"]
# }
# {'detected_topics': [], 'suggested_topics': ['rural_internet']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: I guess just the faster the internet the better. More coverage too but that's coming next year. Basically any way of bringing down the cost is appreciated right now because its so expensive. it's also awesome if you sponsored more stuff for the arts in aotearoa.
# Reason for given NPS: It has good service across the country. better than other networks that's for sure. often my phone is the only one that gets service and that's awesome. love the movie tickets as part of rewards too. also excited for coverage everywhere next year. like the new name too. thanks
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["faster_internet", "better_coverage", "lower_costs", "support_arts_and_culture"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['faster_internet', 'better_coverage', 'lower_costs', 'support_arts_and_culture']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: .
# Reason for given NPS: .
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : []
# }
# {'detected_topics': [], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Cheaper monthly plans when buying a new phone
# Reason for given NPS: The easy process of being able to purchase a new phone
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : []
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Coverage and customer service.
# Reason for given NPS: Just going off personal contact I've had in your shops.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics": [],
#     "suggested_topics": ["coverage", "customer_service"]
# }
# {'detected_topics': [], 'suggested_topics': ['coverage', 'customer_service']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Clearer information on plans and billing, how to choose the best international mobile plan and how to improve my fibre/TV reception.
# Reason for given NPS: I have found that getting clear information on billing and broadband service a bit challenging.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["billing_clarity", "international_roaming_plans", "reception_issues"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['billing_clarity', 'international_roaming_plans', 'reception_issues']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Move your call centre back to NZ and train the staff better
# Reason for given NPS: Pricing is reasonable, especially HFC, however the customer service is below what I expect. In the past 6 months I've had incorrect advice from an instore team member and spent hours on the phone with the call centre trying to get someone to understand my request (which admittedly was probably not a request they come across often).
#
# The English comprehension of the call centre staff I have dealt with is appalling. In 2021 it was announced the One (then Vodafone) call centre would be 'largely based in New Zealand by the end of the year'. I haven't once spoken to a call centre staff member in New Zealand, and, when requested, they have not been able to transfer me to a NZ based staff member. I would rather pay slightly more and have a NZ based call centre with One staff rather than generic call centre staff overseas who may not be employed under conditions that meet NZ minimum standards.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics": ["want_cheaper_pricing"],
#     "suggested_topics": ["poor_customer_service", "offshore_call_center", "need_better_trained_staff"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['poor_customer_service', 'offshore_call_center', 'need_better_trained_staff']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: treat your customers with respect, appreciate their custom, listen to issues and deal with them in realistic meaningful ways. make it easier to actually talk to someone to problem solve, just like learning something new, different people require different methods of communicating.
# Reason for given NPS: had years of bad experiences, only still there due to phones on payment plan
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["customer_service", "improve_communication", "make_contacting_easier", "respect_for_customers"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['customer_service', 'improve_communication', 'make_contacting_easier', 'respect_for_customers']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: More discounts and rewards would be nice
# Reason for given NPS: I've been with one for years. Never had a problem with it.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["rewards_and_discounts"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['rewards_and_discounts']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: No need for so many reminders about paying bills on time especially in the current economic statues
#
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["reduce_bill_reminders", "empathy_for_financial_situation"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['reduce_bill_reminders', 'empathy_for_financial_situation']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Customer service and experience, better communication between technical departments and more cohesive notes taken after calls and emails between service agents.
#
# I have been waiting 5 days for my internet to be rectified after being assured 6 times over phone or email that it should be working.
#
# I will most likely be terminating my broadband and both phones with One NZ as a result of this. Been a customer for 22 years.
# Reason for given NPS: Terrible customer service and experience with moving Broadband this week. Still not resolved after multiple phone calls and emails.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["poor_customer_service", "lack_of_communication", "service_disruption", "cancellation_threat"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['poor_customer_service', 'lack_of_communication', 'service_disruption', 'cancellation_threat']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Don't really know
# Reason for given NPS: I have had no problems.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : []
# }
# {'detected_topics': [], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Some coverage dead spots still were people with other providers have coverage, for example in the lake Hawea area.
# I am looking forward to the 100% text coverage which will be good to have for outdoor adventures and checking in.
# Reason for given NPS: No complaints, but not the sort of thing I would typically recommend
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["poor_network_coverage", "lack_of_features"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['poor_network_coverage', 'lack_of_features']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Clear information on the porting process and what to expect during the transfer. The staff Peter (I may have the name incorrect) gave clear expectations for our numbers to be active on Monday morning but may not have been aware of any effects on the 2fa one time code system. as I changed mobile device as well as provides plus going from e sim to micro sim the transition had a lot of hiccups and delays during the transition. the staff member may not have been aware of this information. as when looking online I could not find a definitive answer about this but heaps of people experience this issue porting numbers. More clear information or follow up email with the ins and outs and what to expect when porting a number. I also feel this is not just a One NZ thing to improve. I had similar issues when changing to 2 Degrees. so industry information that should be clearer for all.
# Reason for given NPS: Really great experience in the Riccarton store completing the sign up/switch to One NZ, I did have a few issues with my number porting from 2 degrees to One, none of the request 2FA codes I would request for signing into my accounts on my new device would come through for the first 48 hours
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics": ["want_cheaper_pricing"],
#     "suggested_topics": ["porting_process_clarity", "porting_expectations", "porting_issues_2fa", "porting_delays", "porting_information"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['porting_process_clarity', 'porting_expectations', 'porting_issues_2fa', 'porting_delays', 'porting_information']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Perhaps make the broadband modem able to use anywhere instead of just at home.I have a motor home and would like to have broadband when I travel.
# Reason for given NPS: I have not had any problems or issues with my plan and I travel all over NZ
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["mobile_broadband", "improve_broadband_accessibility"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['mobile_broadband', 'improve_broadband_accessibility']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Staff escalating issues if they don’t know how to help rather than telling customers to sort themselves and the bills are very confusing and hard to read and understand especially on a mobile phone
# Reason for given NPS: Have been a customer for many years but more recently I have had a couple of issues and have for the first time felt like a number more than a respected loyal customer
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["improve_customer_service", "simplify_billing", "improve_mobile_experience"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['improve_customer_service', 'simplify_billing', 'improve_mobile_experience']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Your website and 0800 number.  It is not helpful to have to speak to someone in India who advises they are unable to help with the problem, and when requesting that I be transferred back to Auckland, am advised that they cannot do that as they are a sub contractor, and do not have the facilities to transfer to back to Auckland. Your website is abysmal.
# Reason for given NPS: Am a little disappointed in One NZ, as am finding neither the website nor the 0800 number very helpful and therefore having difficulties resolving issues. Am v disappointed having been with the company right from Bell South days.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["website_usability", "call_center_experience", "transfer_call_issues", "lack_of_support"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['website_usability', 'call_center_experience', 'transfer_call_issues', 'lack_of_support']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: I don’t know, but I’ll get back to you if I think of anything.
# Reason for given NPS: The app is easy as to use. I like the unlimited data and minutes. One Nz communication is brilliant and I love the ads when you read the tweets or feedback from people 😂😂
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : []
# }
# {'detected_topics': [], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Don't employ that are so hard to deal with they put you in a really bad mood.  Not have to hold on forever.
# Reason for given NPS: Good rating
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : ["complaint_about_customer_service", "long_hold_times"]
# }
# {'detected_topics': [], 'suggested_topics': ['complaint_about_customer_service', 'long_hold_times']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Revisit your charges and start to care about clients that have been with you for years rather than the fickle ones who shift providers regularly
# Reason for given NPS: Coverage during cyclone was appalling. Since cyclone reception is not what it was. Ringing you is a nightmare...you are lucky spark is just as bad!
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["poor_coverage", "poor_customer_service", "network_issues"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['poor_coverage', 'poor_customer_service', 'network_issues']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: As Iv'e been a consistent monthly plan holder for the last 20 years , I think that loyalty should be rewarded . Those who are new customers seem to get reated better than the loyal ones. Just Saying.
# Thanks John Wolfe.
# Reason for given NPS: Enjoying the service , have been a One NZ ( Vodafone) customer for over 20 years now.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["reward_long_term_customers", "better_treatment_for_loyal_customers"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['reward_long_term_customers', 'better_treatment_for_loyal_customers']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Cheaper services
#
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : []
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: You customer service is tribble! Call centres are all overseas and no one know anything about our case. Needing to ring multiple times to get one thing sorted…
#
# Price increase for no real value… why are we paying for your rebranding…
#
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["poor_customer_service", "call_center_issues", "lack_of_knowledge", "multiple_calls_needed", "price_increase_without_value", "paying_for_rebranding"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['poor_customer_service', 'call_center_issues', 'lack_of_knowledge', 'multiple_calls_needed', 'price_increase_without_value', 'paying_for_rebranding']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Reception in some areas is a bit poor but ok overall
#
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["poor_network_reception"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['poor_network_reception']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: More benefits for loyal customers
#
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : ["loyalty_benefits", "rewards_for_loyal_customers"]
# }
# {'detected_topics': [], 'suggested_topics': ['loyalty_benefits', 'rewards_for_loyal_customers']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: For starters, don't address me as Unknown! Your email for this survey said "Kia ora Unknown" as the opening salutation. Doesn't make me feel valued as a customer. You need to improve your mail merge technology.
# Reason for given NPS: It's nothing to shout about.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["improve_mail_merge", "address_customers_properly"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['improve_mail_merge', 'address_customers_properly']}
#
#
# ----------------------------------------------------------
#
#
# Reason for given NPS: Great app, good service so far
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : []
# }
# {'detected_topics': [], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Just cheaper data plan and services in some areas. I live in flatbush... I my house there is less network. Sometime network issue comes.
# Reason for given NPS: I started to use NZ one since I came to new zealand earlier it was nz Vodafone and now it's nz one. Even I bought up my Samsung galaxy s22 from nz one store which is in St lukes. I bought my and my wife's data plan from NZ one and it's giving us best service. Even I recommended nz one network to my friends as well.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["network_coverage_issues", "data_plans"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['network_coverage_issues', 'data_plans']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: call times
# Reason for given NPS: Good Service
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : ["call_wait_times"]
# }
# {'detected_topics': [], 'suggested_topics': ['call_wait_times']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Signal and coverage.
# If spark can have 5G and full coverage and the same address there must be something you can do but apparently not.
# Reason for given NPS: Currently paying two plans and have no signal at my home even though spark has full service. Was told there was only 3G here but can’t even send a text message. Can’t get out of the contracts because paying for the phones. ONE has been no help. I can’t understand why spark has full coverage and 5g but OnE doesn’t/can’t.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics": ["want_cheaper_pricing"],
#     "suggested_topics": ["network_coverage_issues", "poor_signal_quality", "lack_of_5g_availability", "inflexible_contracts", "unsatisfactory_customer_service"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['network_coverage_issues', 'poor_signal_quality', 'lack_of_5g_availability', 'inflexible_contracts', 'unsatisfactory_customer_service']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Ways to get through to support and minimising being directed from pillar to post.
# Reason for given NPS: It’s not perfect but it currently suits my needs.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : ["support_accessibility", "call_routing"]
# }
# {'detected_topics': [], 'suggested_topics': ['support_accessibility', 'call_routing']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Acknowledging your long term customer and not just send an automated email to them a call would be good even it it was for 5years with you guys. Thats my 2 cent.
# God bless
# Reason for given NPS: Been using vodafone/one nz for over 10plus years and wouldn't change it for the world!
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics": [],
#     "suggested_topics": ["acknowledgement_for_long_term_customers", "personal_interaction_instead_of_automated_response"]
# }
# {'detected_topics': [], 'suggested_topics': ['acknowledgement_for_long_term_customers', 'personal_interaction_instead_of_automated_response']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Bring back daily deals..
# Reason for given NPS: I've been with this company for years. Never have I had a bad experience.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : ["bring_back_daily_deals"]
# }
# {'detected_topics': [], 'suggested_topics': ['bring_back_daily_deals']}
#
#
# ----------------------------------------------------------
#
#
# Reason for given NPS: good
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : []
# }
# {'detected_topics': [], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Inbetween data levels for plans.
#
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["want_more_flexible_data_plans"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['want_more_flexible_data_plans']}
#
#
# ----------------------------------------------------------
#
#
# Reason for given NPS: Recent purchase and plans great
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : []
# }
# {'detected_topics': [], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: I wish my monthly payment came straight out of my account instead of having to manually pay every month
# Reason for given NPS: I have never had any issues with One NZ so far. I am on a great plan that works for me
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["billing_payment_issues"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['billing_payment_issues']}
#
#
# ----------------------------------------------------------
#
#
# Reason for given NPS: I find One.NZ  system reasonably  easy to understand and manage.  Reception is good from nearly everywhere.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : []
# }
# {'detected_topics': [], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Just give us a better value plans. Nz is one country in the world that is taking advantage of its customers. It’s all about big profits.
# Reason for given NPS: Not good value for money. Poor data speeds
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["poor_value_for_money", "poor_network_speeds"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['poor_value_for_money', 'poor_network_speeds']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Plans - better plans and cheaper payments
# Services
# Reason for given NPS: Previously have had bad service with this organisation however more recently it has been pleasant as I haven’t had any problems and been able to manage via the app
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["better_plans", "services", "bad_service_experience", "app_experience"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['better_plans', 'services', 'bad_service_experience', 'app_experience']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Plans are still hard to understand especially when moving from an old plan to a new one, and what the final cost will be, the invoice is a complex
#
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["difficult_to_understand_plans", "complex_invoices"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['difficult_to_understand_plans', 'complex_invoices']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: More competitive data plans.
# Reason for given NPS: There's always room for improvement but so far so good based on my experience l.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["competitive_data_plans"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['competitive_data_plans']}
#
#
# ----------------------------------------------------------
#
#
# Reason for given NPS: I have been with this company for 8yrs and I enjoy they service
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : []
# }
# {'detected_topics': [], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Not sure yet
# Reason for given NPS: Never gave it a thought of recommending one nz to anyone
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics": [],
#     "suggested_topics": ["poor_customer_service", "likely_to_not_recommend"]
# }
# {'detected_topics': [], 'suggested_topics': ['poor_customer_service', 'likely_to_not_recommend']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Maybe the One Nz app could be a bit more user friendly and a bit easier to navigate though I didn't really struggle I did notice some things were a bit less clear than others.
#
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : ["app_usability", "app_navigation"]
# }
# {'detected_topics': [], 'suggested_topics': ['app_usability', 'app_navigation']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: N/a
# Reason for given NPS: Billing is easy through the app but on the odd occasion I've had to go in or phone and talk to someone it always an easy process. Great customer service.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : []
# }
# {'detected_topics': [], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Internet connectivity in suburban Auckland it makes it tricky to work from home
# Reason for given NPS: Internet connection is unreliable in central Auckland
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["poor_internet_connectivity", "unreliable_internet_connection"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['poor_internet_connectivity', 'unreliable_internet_connection']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Connectivity speed, pricing, coverage
# Reason for given NPS: Site unstable
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["poor_connectivity_speed", "poor_coverage", "site_instability"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['poor_connectivity_speed', 'poor_coverage', 'site_instability']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Competitiveness
# You are not seen as hungry for business.
# Reason for given NPS: Pricing plans are not as competitive as others. The cost of roaming is very high. Poor coverage in some areas in Auckland. The charge for using credit card to pay the bill is too much.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["poor_network_coverage", "high_roaming_charges", "credit_card_payment_fee_high", "uncompetitive_pricing_plans", "lack_of_hunger_for_business"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['poor_network_coverage', 'high_roaming_charges', 'credit_card_payment_fee_high', 'uncompetitive_pricing_plans', 'lack_of_hunger_for_business']}
#
#
# ----------------------------------------------------------
#
#
# Improvement needed: Nothing specific to add.  Value for money will be the ongoing consideration.
# Reason for given NPS: Have had reliable performance, lack of attractive deals though right now though.  Mobile data add-ons are handy.
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : ["want_cheaper_pricing"],
#     "suggested_topics" : ["lack_of_attractive_deals", "need_better_value_for_money"]
# }
# {'detected_topics': ['want_cheaper_pricing'], 'suggested_topics': ['lack_of_attractive_deals', 'need_better_value_for_money']}
#
#
# ----------------------------------------------------------
#
#
# Reason for given NPS: Never had any issues
# Sending request to LLM
# Received response from LLM.
# llm response {
#     "detected_topics" : [],
#     "suggested_topics" : []
# }
# {'detected_topics': [], 'suggested_topics': []}
#
#
# ----------------------------------------------------------
